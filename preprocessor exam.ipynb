# %%
import pandas as pd

# %%
data=pd.read_csv('Data_Train_1.csv')

# %%
data
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# ...

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
# Airline            10683 non-null object
# Date_of_Journey    10683 non-null object
# Source             10683 non-null object
# Destination        10683 non-null object
# Route              10682 non-null object
# Dep_Time           10683 non-null object
# Arrival_Time       10683 non-null object
# Duration           10683 non-null object
# Total_Stops        10682 non-null object
# Additional_Info    10683 non-null object
# Price              10683 non-null int64
# dtypes: int64(1), object(10)
# memory usage: 918.1+ KB

# %%
data.fillna(method='ffill',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
a=LabelEncoder()

# %%
data.Route=a.fit_transform(data.Route)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination  Route Dep_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi     18    22:20
# 1    Air India       1/05/2019   Kolkata    Banglore     84    05:50
# 2  Jet Airways       9/06/2019     Delhi      Cochin    118    09:25
# 3       IndiGo      12/05/2019   Kolkata    Banglore     91    18:05
# 4       IndiGo      01/03/2019  Banglore   New Delhi     29    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1         13:15   7h 25m     2 stops         No info   7662
# 2  04:25 10 Jun      19h     2 stops         No info  13882
# 3         23:30   5h 25m      1 stop         No info   6218
# 4         21:35   4h 45m      1 stop         No info  13302

# %%
data.Source.dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
# Airline            10683 non-null object
# Date_of_Journey    10683 non-null object
# Source             10683 non-null object
# Destination        10683 non-null object
# Route              10683 non-null int64
# Dep_Time           10683 non-null object
# Arrival_Time       10683 non-null object
# Duration           10683 non-null object
# Total_Stops        10683 non-null object
# Additional_Info    10683 non-null object
# Price              10683 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 918.1+ KB

# %%
data.Source=a.fit_transform(data.Source)
data.Destination=a.fit_transform(data.Destination)
data.head()
# Out:
#        Airline Date_of_Journey  Source  Destination  Route Dep_Time  \
# 0       IndiGo      24/03/2019       0            5     18    22:20
# 1    Air India       1/05/2019       3            0     84    05:50
# 2  Jet Airways       9/06/2019       2            1    118    09:25
# 3       IndiGo      12/05/2019       3            0     91    18:05
# 4       IndiGo      01/03/2019       0            5     29    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1         13:15   7h 25m     2 stops         No info   7662
# 2  04:25 10 Jun      19h     2 stops         No info  13882
# 3         23:30   5h 25m      1 stop         No info   6218
# 4         21:35   4h 45m      1 stop         No info  13302

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
# Airline            10683 non-null object
# Date_of_Journey    10683 non-null object
# Source             10683 non-null int64
# Destination        10683 non-null int64
# Route              10683 non-null int64
# Dep_Time           10683 non-null object
# Arrival_Time       10683 non-null object
# Duration           10683 non-null object
# Total_Stops        10683 non-null object
# Additional_Info    10683 non-null object
# Price              10683 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 918.1+ KB

# %%
data.Source=data.Source.astype(float)
data.Destination=data.Destination.astype(float)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
# Airline            10683 non-null object
# Date_of_Journey    10683 non-null object
# Source             10683 non-null float64
# Destination        10683 non-null float64
# Route              10683 non-null int64
# Dep_Time           10683 non-null object
# Arrival_Time       10683 non-null object
# Duration           10683 non-null object
# Total_Stops        10683 non-null object
# Additional_Info    10683 non-null object
# Price              10683 non-null int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 918.1+ KB
